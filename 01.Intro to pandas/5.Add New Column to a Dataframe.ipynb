# %%
import pandas as pd

# %%
#reading the csv file
df_exams=pd.read_csv('50_Startups.csv')
df_exams
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# # 1 Adding a new column

# %% [markdown]
# ## 1.1 Adding a new column with a scalar value

# %%
# adding new column to dataframe
df_exams['Favorite Country']='India'
df_exams
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# ## 1.2 Adding a new column with an array

# %% [markdown]
# ##### The dataframe has 50 rows , so we need to create an array with 1000 elements

# %%
# import numpy
import numpy as np

# %%
# create an array of 50 elements
State_score=np.arange(0,50)

# %%
# len of array
len(np.arange(0,50))
# Out:
# 50

# %%
# adding a new column to data frame with an array
df_exams['Favourite Country']=State_score

# %%
df_exams
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
# create random integer numbers between 1 and 100
Fav_country_rate=np.random.randint(1,10,size=50)

# %%
# min value inclusive and high value exclusive 
min(Fav_country_rate)
# Out:
# np.int32(1)

# %%
# adding a new column to dataframe with an array
df_exams['Favourite Country rate']=Fav_country_rate
df_exams
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
# create a random float numbers betweeen 1 and 100
np.random.uniform(1,100,size=100)
# Out:
# array([53.64871071, 68.37818933, 20.37184321, 59.95419528, 60.43606228,
#        34.1361065 , 38.35738427, 90.55732707, 81.20590675, 60.35523691,
#        62.26263661, 71.682623  , 43.10768314, 30.38119965,  4.29569873,
#         9.95081681, 96.24406894, 53.01732677,  2.61301879, 85.32611537,
#        42.82982755, 85.83910882, 45.18593203, 42.05758216, 11.25153458,
#        58.94012399, 15.15938892,  9.52326067, 62.60497995, 60.27890355,
#        23.71739965, 75.12050564,  7.71273336, 18.23943619, 49.78189552,
#        10.23252044,  4.83536957, 48.97987494, 47.19193963, 57.43950562,
#        88.31268607, 29.12664678, 61.89824186, 32.69415894, 14.74043406,
#        69.20391054, 79.04959696, 63.61049664, 83.31955101, 11.54935426,
#        41.97166943, 45.89947026, 68.11784835, 65.15697549, 97.47561492,
#        72.16071474, 49.53815821, 62.44519105, 93.25707545, 77.04967688,
#        70.05627401, 73.34332096,  3.64217282, 13.636853  , 33.90356876,
# ...
