# %%
import pandas as pd
df_laptops= pd.read_csv('laptop_data.csv')
df_laptops.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %% [markdown]
# # 1 Duplicate

# %% [markdown]
# ## 1.1 Example 1

# %%
# find duplicates in 1 column/series
df_laptops.duplicated('Ram').head(6)
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
# show elements in dataframe with duplicates in column 'Laptop_ID'
df_laptops[df_laptops.duplicated('Ram')]
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 4              4   Apple           Ultrabook    13.3
# 6              6   Apple           Ultrabook    15.4
# 7              7   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 4             IPS Panel Retina Display 2560x1600
# 6             IPS Panel Retina Display 2880x1800
# 7                                       1440x900
# ...

# %%
# duplicate in 2 or more columns
df_laptops.duplicated(['Company','TypeName','Inches'])
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 1298     True
# 1299     True
# 1300     True
# 1301     True
# 1302     True
# Length: 1303, dtype: bool

# %%
# show all the values duplicated (except for the first - keep='first')
df_laptops[df_laptops.duplicated(['Company','TypeName','Inches'])]
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 1              1   Apple           Ultrabook    13.3
# 4              4   Apple           Ultrabook    13.3
# 6              6   Apple           Ultrabook    15.4
# 7              7   Apple           Ultrabook    13.3
# 10            10      HP            Notebook    15.6
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 1                                       1440x900
# 4             IPS Panel Retina Display 2560x1600
# 6             IPS Panel Retina Display 2880x1800
# 7                                       1440x900
# 10                                      1366x768
# ...

# %% [markdown]
# # 1.2 Example 2

# %% [markdown]
# #### task: Find the cheapest and most expensive laptop of each company using the sort_values() and duplicated() method(keep "first","last" and False)

# %%
# sort dataframe ascending by company and price 
# cheapest first and most expensive last
df_laptops=df_laptops.sort_values(['Company','Price'])
df_laptops
# Out:
#       Unnamed: 0 Company   TypeName  Inches             ScreenResolution  \
# 1215        1215    Acer    Netbook    11.6                     1366x768
# 290          290    Acer   Notebook    15.6                     1366x768
# 1102        1102    Acer   Notebook    15.6                     1366x768
# 695          695    Acer    Netbook    11.6                     1366x768
# 1198        1198    Acer   Notebook    15.6                     1366x768
# ...          ...     ...        ...     ...                          ...
# 191          191    Vero   Notebook    14.0  IPS Panel Full HD 1920x1080
# 877          877  Xiaomi  Ultrabook    13.3  IPS Panel Full HD 1920x1080
# 192          192  Xiaomi  Ultrabook    13.3  IPS Panel Full HD 1920x1080
# 184          184  Xiaomi   Notebook    15.6  IPS Panel Full HD 1920x1080
# 514          514  Xiaomi   Notebook    15.6  IPS Panel Full HD 1920x1080
#
#                                        Cpu   Ram              Memory  \
# ...

# %%
# check all values categories in "company" column
df_laptops.value_counts('Company')
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# LG             3
# Google         3
# Huawei         2
# Name: count, dtype: int64

# %%
# duplicated valued in "company"columns (default -> keep='first')
duplicated_first=df_laptops.duplicated('Company', keep='first')
duplicated_first
# Out:
# 1215    False
# 290      True
# 1102     True
# 695      True
# 1198     True
#         ...
# 191      True
# 877     False
# 192      True
# 184      True
# 514      True
# Length: 1303, dtype: bool

# %%
# keep='first'(cheapest laptop per company)
df_laptops[~duplicated_first][['Company','Price']]
# Out:
#         Company        Price
# 1215       Acer    9270.7200
# 1         Apple   47895.5232
# 20         Asus   10224.4320
# 30        Chuwi   13053.0672
# 340        Dell   14646.6720
# 983     Fujitsu   34578.7200
# 472      Google   67932.0000
# 1268         HP   11135.5200
# 170      Huawei   71874.7200
# 909          LG  101178.7200
# 1272     Lenovo   12201.1200
# 1169        MSI   44701.9200
# 626    Mediacom   12733.9200
# 457   Microsoft   52693.9200
# 1117      Razer   54825.1200
# 430     Samsung   14332.3200
# 159     Toshiba   23816.1600
# 1120       Vero   10442.8800
# 877      Xiaomi   49816.8000

# %%
# show dataframe with duplicated values in the "Company" column
df_laptops[duplicated_first]


# show dataframe with non duplicated values in "company" column
df_laptops[~duplicated_first].value_counts('Company')
# Out:
# Company
# Acer         1
# Apple        1
# Asus         1
# Chuwi        1
# Dell         1
# Fujitsu      1
# Google       1
# HP           1
# Huawei       1
# LG           1
# Lenovo       1
# MSI          1
# Mediacom     1
# Microsoft    1
# Razer        1
# Samsung      1
# Toshiba      1
# Vero         1
# Xiaomi       1
# Name: count, dtype: int64

# %%
# keep ='last'
duplicated_last=df_laptops.duplicated('Company', keep='last')
# keep=false
duplicated_false=df_laptops.duplicated('Company', keep=False)

# %%
# keep ='last' (most expensive laptop per company)
# show dataframe with non duplicated values in "company" column
df_laptops[~duplicated_last][['Company','Price']]
# Out:
#         Company       Price
# 1189       Acer  138474.720
# 17        Apple  152274.240
# 1066       Asus  211788.000
# 421       Chuwi   23922.720
# 723        Dell  194972.832
# 623     Fujitsu   42570.720
# 437      Google  117162.720
# 749          HP  233845.920
# 214      Huawei   79866.720
# 678          LG  122490.720
# 610      Lenovo  261018.720
# 177         MSI  149130.720
# 580    Mediacom   20725.920
# 449   Microsoft  137941.920
# 196       Razer  324954.720
# 874     Samsung   98514.720
# 491     Toshiba  149130.720
# 191        Vero   13852.800
# 514      Xiaomi   74589.336

# %%
# keep =False (most expensive laptop per company)
# show dataframe with non duplicated values in "company" column

df_laptops[~duplicated_false]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Company, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price]
# Index: []

# %%
# all elements in company column are repeated at least once
df_laptops.value_counts('Company')
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# LG             3
# Google         3
# Huawei         2
# Name: count, dtype: int64
